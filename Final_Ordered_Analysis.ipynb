# %% [markdown]
# # GOAT Index: Análisis Comparativo de Michael Jordan, Kobe Bryant y LeBron James
#
# ## Introducción
#
# El debate sobre quién es el mejor jugador de la historia de la NBA (GOAT – Greatest Of All Time) es uno de los más recurrentes y polémicos en el deporte.
#
# Este proyecto busca construir un **índice cuantitativo (GOAT Index)** que combine:
# - rendimiento ofensivo
# - impacto defensivo
# - eficiencia
# - éxito colectivo (títulos)
# para comparar a tres de los principales candidatos al GOAT:
# **Michael Jordan, Kobe Bryant y LeBron James**.
#
# El análisis se apoya en datos oficiales de la NBA y en datasets históricos, con el objetivo de ofrecer una comparación transparente, reproducible y defendible.

# %%
import pandas as pd
import numpy as np

from nba_api.stats.endpoints import playercareerstats

# %%
players = pd.read_csv("/Users/lautarocardinisilvestri/Downloads/Ironhack/Semana 4/Proyecto NBA/NBA_PLAYERS.csv")
teams = pd.read_csv("/Users/lautarocardinisilvestri/Downloads/Ironhack/Semana 4/Proyecto NBA/NBA_TEAMS.csv")
finals = pd.read_csv("/Users/lautarocardinisilvestri/Downloads/Ironhack/Semana 4/Proyecto NBA/NBA_Finals_and_MVP.csv")

# %%
GOATS_IDS = {
    "Michael Jordan": 893,
    "Kobe Bryant": 977,
    "LeBron James": 2544
}

# %%
def get_player_career(player_name, player_id):
    career = playercareerstats.PlayerCareerStats(player_id=player_id)
    df = career.get_data_frames()[0]
    df["PLAYER_NAME"] = player_name
    return df

# %%
dfs = []

for name, pid in GOATS_IDS.items():
    dfs.append(get_player_career(name, pid))

career_df = pd.concat(dfs, ignore_index=True)

# %%
career_df[["PLAYER_NAME", "SEASON_ID", "GP", "MIN", "PTS"]].head()
# Out:
#       PLAYER_NAME SEASON_ID  GP   MIN   PTS
# 0  Michael Jordan   1984-85  82  3144  2313
# 1  Michael Jordan   1985-86  18   451   408
# 2  Michael Jordan   1986-87  82  3281  3041
# 3  Michael Jordan   1987-88  82  3311  2868
# 4  Michael Jordan   1988-89  81  3255  2633

# %%
finals.columns
# Out:
# Index(['index', 'Year', 'Western Champion', 'Eastern Champion', 'Result',
#        'NBA Champion', 'NBA Vice-Champion', 'Final Sweep ?', 'MVP Name',
#        'MVP Height (m)', 'MVP Height (ft)', 'MVP Position', 'MVP Team',
#        'MVP Nationality', 'MVP status'],
#       dtype='object')

# %% [markdown]
# ## Preparación de los datos
#
# En esta sección se limpian y transforman las estadísticas originales
# para obtener métricas comparables entre jugadores con diferentes
# minutos y contextos de juego.
#
# Se utilizan métricas normalizadas por minuto y por 36 minutos,
# estándar común en análisis NBA.

# %%
cols_clean = [
    "PLAYER_NAME", "SEASON_ID", "GP", "MIN",
    "PTS", "REB", "AST", "STL", "BLK",
    "FG_PCT", "FG3_PCT", "FT_PCT"
]

GOAT_df = career_df[cols_clean].copy()
GOAT_df.head()
# Out:
#       PLAYER_NAME SEASON_ID  GP   MIN   PTS  REB  AST  STL  BLK  FG_PCT  \
# 0  Michael Jordan   1984-85  82  3144  2313  534  481  196   69   0.515
# 1  Michael Jordan   1985-86  18   451   408   64   53   37   21   0.457
# 2  Michael Jordan   1986-87  82  3281  3041  430  377  236  125   0.482
# 3  Michael Jordan   1987-88  82  3311  2868  449  485  259  131   0.535
# 4  Michael Jordan   1988-89  81  3255  2633  652  650  234   65   0.538
#
#    FG3_PCT  FT_PCT
# 0    0.173   0.845
# 1    0.167   0.840
# 2    0.182   0.857
# 3    0.132   0.841
# 4    0.276   0.850

# %%
for stat in ["PTS", "REB", "AST", "STL", "BLK"]:
    GOAT_df[f"{stat}_PER_MIN"] = GOAT_df[stat] / GOAT_df["MIN"]

GOAT_df[
    ["PLAYER_NAME", "SEASON_ID", "MIN",
     "PTS_PER_MIN", "REB_PER_MIN", "AST_PER_MIN"]
].head()
# Out:
#       PLAYER_NAME SEASON_ID   MIN  PTS_PER_MIN  REB_PER_MIN  AST_PER_MIN
# 0  Michael Jordan   1984-85  3144     0.735687     0.169847     0.152990
# 1  Michael Jordan   1985-86   451     0.904656     0.141907     0.117517
# 2  Michael Jordan   1986-87  3281     0.926852     0.131058     0.114904
# 3  Michael Jordan   1987-88  3311     0.866204     0.135609     0.146481
# 4  Michael Jordan   1988-89  3255     0.808909     0.200307     0.199693

# %%
for stat in ["PTS", "REB", "AST", "STL", "BLK"]:
    GOAT_df[f"{stat}_PER_36"] = GOAT_df[f"{stat}_PER_MIN"] * 36

GOAT_df[
    ["PLAYER_NAME", "SEASON_ID",
     "PTS_PER_36", "REB_PER_36", "AST_PER_36",
     "STL_PER_36", "BLK_PER_36"]
].head()
# Out:
#       PLAYER_NAME SEASON_ID  PTS_PER_36  REB_PER_36  AST_PER_36  STL_PER_36  \
# 0  Michael Jordan   1984-85   26.484733    6.114504    5.507634    2.244275
# 1  Michael Jordan   1985-86   32.567627    5.108647    4.230599    2.953437
# 2  Michael Jordan   1986-87   33.366657    4.718074    4.136544    2.589454
# 3  Michael Jordan   1987-88   31.183328    4.881909    5.273331    2.816068
# 4  Michael Jordan   1988-89   29.120737    7.211060    7.188940    2.588018
#
#    BLK_PER_36
# 0    0.790076
# 1    1.676275
# 2    1.371533
# 3    1.424343
# 4    0.718894

# %%
metrics_GOAT = GOAT_df[
    [
        "PLAYER_NAME", "SEASON_ID",
        "PTS_PER_36", "REB_PER_36", "AST_PER_36",
        "STL_PER_36", "BLK_PER_36",
        "FG_PCT", "FG3_PCT", "FT_PCT"
    ]
].copy()

metrics_GOAT.head()
# Out:
#       PLAYER_NAME SEASON_ID  PTS_PER_36  REB_PER_36  AST_PER_36  STL_PER_36  \
# 0  Michael Jordan   1984-85   26.484733    6.114504    5.507634    2.244275
# 1  Michael Jordan   1985-86   32.567627    5.108647    4.230599    2.953437
# 2  Michael Jordan   1986-87   33.366657    4.718074    4.136544    2.589454
# 3  Michael Jordan   1987-88   31.183328    4.881909    5.273331    2.816068
# 4  Michael Jordan   1988-89   29.120737    7.211060    7.188940    2.588018
#
#    BLK_PER_36  FG_PCT  FG3_PCT  FT_PCT
# 0    0.790076   0.515    0.173   0.845
# 1    1.676275   0.457    0.167   0.840
# 2    1.371533   0.482    0.182   0.857
# 3    1.424343   0.535    0.132   0.841
# 4    0.718894   0.538    0.276   0.850

# %% [markdown]
# DEFINIMOS LA TRAYECTORIA DE LOS TRES JUGADORES PARA CONOCER LOS EQUIPOS DONDE JUGARON Y SI, EN SU CARRERA, OBTUVIERON TÍTULOS

# %%
player_teams = {
    "Michael Jordan": ["Chicago Bulls"],
    "Kobe Bryant": ["Los Angeles Lakers"],
    "LeBron James": ["Miami Heat", "Cleveland Cavaliers", "Los Angeles Lakers"]
}

# %%
championships_df = pd.DataFrame({
    "PLAYER_NAME": ["Michael Jordan", "Kobe Bryant", "LeBron James"],
    "CHAMPIONSHIPS": [6, 5, 4]
})

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

# %%
goat_scaled = metrics_GOAT.copy()

cols_to_scale = [
    "PTS_PER_36",
    "REB_PER_36",
    "AST_PER_36",
    "STL_PER_36",
    "BLK_PER_36",
    "FG_PCT",
    "FG3_PCT",
    "FT_PCT"
]

goat_scaled[cols_to_scale] = scaler.fit_transform(
    goat_scaled[cols_to_scale]
)

# %%
weights = {
    "PTS_PER_36": 0.25,
    "REB_PER_36": 0.15,
    "AST_PER_36": 0.15,
    "STL_PER_36": 0.05,
    "BLK_PER_36": 0.05,
    "FG_PCT": 0.15,
    "FG3_PCT": 0.10,
    "FT_PCT": 0.10
}

goat_scaled["GOAT_INDEX"] = sum(
    goat_scaled[m] * w for m, w in weights.items()
)

# %%
goat_final = goat_scaled[["PLAYER_NAME", "GOAT_INDEX"]].copy()

# %% [markdown]
# NORMALIZAMOS Y PONDERAMOS LA VARIABLE "CAMPEONATOS" PARA INCLUIRLA EN NUESTRO ANÁLISIS

# %%
championships_df["CHAMPIONSHIPS_NORM"] = (
    championships_df["CHAMPIONSHIPS"] /
    championships_df["CHAMPIONSHIPS"].max()
)

# %% [markdown]
# INTEGRAMOS LOS DOS DF A FINES QUE QUEDEN UNIDOS Y CONTRIBUYAN A SU ANÁLISIS FINAL

# %%
goat_final = goat_final.merge(
    championships_df[["PLAYER_NAME", "CHAMPIONSHIPS_NORM"]],
    on="PLAYER_NAME",
    how="left"
)

# %%
goat_final
# Out:
#        PLAYER_NAME  GOAT_INDEX  CHAMPIONSHIPS_NORM
# 0   Michael Jordan    0.525108            1.000000
# 1   Michael Jordan    0.558956            1.000000
# 2   Michael Jordan    0.567350            1.000000
# 3   Michael Jordan    0.585963            1.000000
# 4   Michael Jordan    0.688427            1.000000
# 5   Michael Jordan    0.674839            1.000000
# 6   Michael Jordan    0.649937            1.000000
# 7   Michael Jordan    0.565787            1.000000
# 8   Michael Jordan    0.603250            1.000000
# 9   Michael Jordan    0.464751            1.000000
# 10  Michael Jordan    0.578977            1.000000
# 11  Michael Jordan    0.507490            1.000000
# 12  Michael Jordan    0.384230            1.000000
# 13  Michael Jordan    0.346073            1.000000
# 14  Michael Jordan    0.316122            1.000000
# 15     Kobe Bryant    0.234116            0.833333
# 16     Kobe Bryant    0.275677            0.833333
# 17     Kobe Bryant    0.305885            0.833333
# 18     Kobe Bryant    0.400066            0.833333
# 19     Kobe Bryant    0.425535            0.833333
# 20     Kobe Bryant    0.390602            0.833333
# 21     Kobe Bryant    0.504853            0.833333
# 22     Kobe Bryant    0.391241            0.833333
# 23     Kobe Bryant    0.402192            0.833333
# 24     Kobe Bryant    0.488104            0.833333
# 25     Kobe Bryant    0.478172            0.833333
# 26     Kobe Bryant    0.484634            0.833333
# 27     Kobe Bryant    0.474897            0.833333
# 28     Kobe Bryant    0.392360            0.833333
# 29     Kobe Bryant    0.440810            0.833333
# 30     Kobe Bryant    0.388015            0.833333
# 31     Kobe Bryant    0.440342            0.833333
# 32     Kobe Bryant    0.300749            0.833333
# 33     Kobe Bryant    0.353377            0.833333
# 34     Kobe Bryant    0.244716            0.833333
# 35    LeBron James    0.265970            0.666667
# 36    LeBron James    0.444655            0.666667
# 37    LeBron James    0.462643            0.666667
# 38    LeBron James    0.391468            0.666667
# 39    LeBron James    0.520166            0.666667
# 40    LeBron James    0.591202            0.666667
# 41    LeBron James    0.590038            0.666667
# 42    LeBron James    0.517995            0.666667
# 43    LeBron James    0.593447            0.666667
# 44    LeBron James    0.628656            0.666667
# 45    LeBron James    0.556941            0.666667
# 46    LeBron James    0.482263            0.666667
# 47    LeBron James    0.542380            0.666667
# 48    LeBron James    0.589951            0.666667
# 49    LeBron James    0.671252            0.666667
# 50    LeBron James    0.615855            0.666667
# 51    LeBron James    0.617687            0.666667
# 52    LeBron James    0.607284            0.666667
# 53    LeBron James    0.635999            0.666667
# 54    LeBron James    0.626023            0.666667
# 55    LeBron James    0.627872            0.666667
# 56    LeBron James    0.614868            0.666667
# 57    LeBron James    0.476675            0.666667

# %%
goat_final["GOAT_INDEX_FINAL"] = (
    goat_final["GOAT_INDEX"] * 0.9 +
    goat_final["CHAMPIONSHIPS_NORM"] * 0.1
)

# %%
goat_final = goat_final.sort_values(
    "GOAT_INDEX_FINAL",
    ascending=False
).reset_index(drop=True)

# %%
goat_final[[
    "PLAYER_NAME",
    "GOAT_INDEX_FINAL",
    "GOAT_INDEX",
    "CHAMPIONSHIPS_NORM"
]]
# Out:
#        PLAYER_NAME  GOAT_INDEX_FINAL  GOAT_INDEX  CHAMPIONSHIPS_NORM
# 0   Michael Jordan          0.719585    0.688427            1.000000
# 1   Michael Jordan          0.707355    0.674839            1.000000
# 2   Michael Jordan          0.684943    0.649937            1.000000
# 3     LeBron James          0.670794    0.671252            0.666667
# 4   Michael Jordan          0.642925    0.603250            1.000000
# 5     LeBron James          0.639066    0.635999            0.666667
# 6     LeBron James          0.632457    0.628656            0.666667
# 7     LeBron James          0.631752    0.627872            0.666667
# 8     LeBron James          0.630088    0.626023            0.666667
# 9   Michael Jordan          0.627367    0.585963            1.000000
# 10    LeBron James          0.622585    0.617687            0.666667
# 11  Michael Jordan          0.621080    0.578977            1.000000
# 12    LeBron James          0.620936    0.615855            0.666667
# 13    LeBron James          0.620048    0.614868            0.666667
# 14    LeBron James          0.613222    0.607284            0.666667
# 15  Michael Jordan          0.610615    0.567350            1.000000
# 16  Michael Jordan          0.609208    0.565787            1.000000
# 17  Michael Jordan          0.603061    0.558956            1.000000
# 18    LeBron James          0.600769    0.593447            0.666667
# 19    LeBron James          0.598749    0.591202            0.666667
# 20    LeBron James          0.597701    0.590038            0.666667
# 21    LeBron James          0.597623    0.589951            0.666667
# 22  Michael Jordan          0.572597    0.525108            1.000000
# 23    LeBron James          0.567913    0.556941            0.666667
# 24  Michael Jordan          0.556741    0.507490            1.000000
# 25    LeBron James          0.554809    0.542380            0.666667
# 26     Kobe Bryant          0.537701    0.504853            0.833333
# 27    LeBron James          0.534816    0.520166            0.666667
# 28    LeBron James          0.532862    0.517995            0.666667
# 29     Kobe Bryant          0.522627    0.488104            0.833333
# 30     Kobe Bryant          0.519504    0.484634            0.833333
# 31  Michael Jordan          0.518276    0.464751            1.000000
# 32     Kobe Bryant          0.513688    0.478172            0.833333
# 33     Kobe Bryant          0.510741    0.474897            0.833333
# 34    LeBron James          0.500704    0.482263            0.666667
# 35    LeBron James          0.495675    0.476675            0.666667
# 36    LeBron James          0.483045    0.462643            0.666667
# 37     Kobe Bryant          0.480063    0.440810            0.833333
# 38     Kobe Bryant          0.479641    0.440342            0.833333
# 39    LeBron James          0.466856    0.444655            0.666667
# 40     Kobe Bryant          0.466315    0.425535            0.833333
# 41  Michael Jordan          0.445807    0.384230            1.000000
# 42     Kobe Bryant          0.445306    0.402192            0.833333
# 43     Kobe Bryant          0.443393    0.400066            0.833333
# 44     Kobe Bryant          0.436457    0.392360            0.833333
# 45     Kobe Bryant          0.435450    0.391241            0.833333
# 46     Kobe Bryant          0.434875    0.390602            0.833333
# 47     Kobe Bryant          0.432547    0.388015            0.833333
# 48    LeBron James          0.418988    0.391468            0.666667
# 49  Michael Jordan          0.411466    0.346073            1.000000
# 50     Kobe Bryant          0.401372    0.353377            0.833333
# 51  Michael Jordan          0.384510    0.316122            1.000000
# 52     Kobe Bryant          0.358630    0.305885            0.833333
# 53     Kobe Bryant          0.354008    0.300749            0.833333
# 54     Kobe Bryant          0.331443    0.275677            0.833333
# 55    LeBron James          0.306039    0.265970            0.666667
# 56     Kobe Bryant          0.303578    0.244716            0.833333
# 57     Kobe Bryant          0.294038    0.234116            0.833333

# %%
ranking_final = goat_final[[
    "PLAYER_NAME",
    "GOAT_INDEX_FINAL",
    "GOAT_INDEX",
    "CHAMPIONSHIPS_NORM"
]].copy()

ranking_final
# Out:
#        PLAYER_NAME  GOAT_INDEX_FINAL  GOAT_INDEX  CHAMPIONSHIPS_NORM
# 0   Michael Jordan          0.719585    0.688427            1.000000
# 1   Michael Jordan          0.707355    0.674839            1.000000
# 2   Michael Jordan          0.684943    0.649937            1.000000
# 3     LeBron James          0.670794    0.671252            0.666667
# 4   Michael Jordan          0.642925    0.603250            1.000000
# 5     LeBron James          0.639066    0.635999            0.666667
# 6     LeBron James          0.632457    0.628656            0.666667
# 7     LeBron James          0.631752    0.627872            0.666667
# 8     LeBron James          0.630088    0.626023            0.666667
# 9   Michael Jordan          0.627367    0.585963            1.000000
# 10    LeBron James          0.622585    0.617687            0.666667
# 11  Michael Jordan          0.621080    0.578977            1.000000
# 12    LeBron James          0.620936    0.615855            0.666667
# 13    LeBron James          0.620048    0.614868            0.666667
# 14    LeBron James          0.613222    0.607284            0.666667
# 15  Michael Jordan          0.610615    0.567350            1.000000
# 16  Michael Jordan          0.609208    0.565787            1.000000
# 17  Michael Jordan          0.603061    0.558956            1.000000
# 18    LeBron James          0.600769    0.593447            0.666667
# 19    LeBron James          0.598749    0.591202            0.666667
# 20    LeBron James          0.597701    0.590038            0.666667
# 21    LeBron James          0.597623    0.589951            0.666667
# 22  Michael Jordan          0.572597    0.525108            1.000000
# 23    LeBron James          0.567913    0.556941            0.666667
# 24  Michael Jordan          0.556741    0.507490            1.000000
# 25    LeBron James          0.554809    0.542380            0.666667
# 26     Kobe Bryant          0.537701    0.504853            0.833333
# 27    LeBron James          0.534816    0.520166            0.666667
# 28    LeBron James          0.532862    0.517995            0.666667
# 29     Kobe Bryant          0.522627    0.488104            0.833333
# 30     Kobe Bryant          0.519504    0.484634            0.833333
# 31  Michael Jordan          0.518276    0.464751            1.000000
# 32     Kobe Bryant          0.513688    0.478172            0.833333
# 33     Kobe Bryant          0.510741    0.474897            0.833333
# 34    LeBron James          0.500704    0.482263            0.666667
# 35    LeBron James          0.495675    0.476675            0.666667
# 36    LeBron James          0.483045    0.462643            0.666667
# 37     Kobe Bryant          0.480063    0.440810            0.833333
# 38     Kobe Bryant          0.479641    0.440342            0.833333
# 39    LeBron James          0.466856    0.444655            0.666667
# 40     Kobe Bryant          0.466315    0.425535            0.833333
# 41  Michael Jordan          0.445807    0.384230            1.000000
# 42     Kobe Bryant          0.445306    0.402192            0.833333
# 43     Kobe Bryant          0.443393    0.400066            0.833333
# 44     Kobe Bryant          0.436457    0.392360            0.833333
# 45     Kobe Bryant          0.435450    0.391241            0.833333
# 46     Kobe Bryant          0.434875    0.390602            0.833333
# 47     Kobe Bryant          0.432547    0.388015            0.833333
# 48    LeBron James          0.418988    0.391468            0.666667
# 49  Michael Jordan          0.411466    0.346073            1.000000
# 50     Kobe Bryant          0.401372    0.353377            0.833333
# 51  Michael Jordan          0.384510    0.316122            1.000000
# 52     Kobe Bryant          0.358630    0.305885            0.833333
# 53     Kobe Bryant          0.354008    0.300749            0.833333
# 54     Kobe Bryant          0.331443    0.275677            0.833333
# 55    LeBron James          0.306039    0.265970            0.666667
# 56     Kobe Bryant          0.303578    0.244716            0.833333
# 57     Kobe Bryant          0.294038    0.234116            0.833333

# %%
ranking_final = ranking_final.round(3)
ranking_final
# Out:
#        PLAYER_NAME  GOAT_INDEX_FINAL  GOAT_INDEX  CHAMPIONSHIPS_NORM
# 0   Michael Jordan             0.720       0.688               1.000
# 1   Michael Jordan             0.707       0.675               1.000
# 2   Michael Jordan             0.685       0.650               1.000
# 3     LeBron James             0.671       0.671               0.667
# 4   Michael Jordan             0.643       0.603               1.000
# 5     LeBron James             0.639       0.636               0.667
# 6     LeBron James             0.632       0.629               0.667
# 7     LeBron James             0.632       0.628               0.667
# 8     LeBron James             0.630       0.626               0.667
# 9   Michael Jordan             0.627       0.586               1.000
# 10    LeBron James             0.623       0.618               0.667
# 11  Michael Jordan             0.621       0.579               1.000
# 12    LeBron James             0.621       0.616               0.667
# 13    LeBron James             0.620       0.615               0.667
# 14    LeBron James             0.613       0.607               0.667
# 15  Michael Jordan             0.611       0.567               1.000
# 16  Michael Jordan             0.609       0.566               1.000
# 17  Michael Jordan             0.603       0.559               1.000
# 18    LeBron James             0.601       0.593               0.667
# 19    LeBron James             0.599       0.591               0.667
# 20    LeBron James             0.598       0.590               0.667
# 21    LeBron James             0.598       0.590               0.667
# 22  Michael Jordan             0.573       0.525               1.000
# 23    LeBron James             0.568       0.557               0.667
# 24  Michael Jordan             0.557       0.507               1.000
# 25    LeBron James             0.555       0.542               0.667
# 26     Kobe Bryant             0.538       0.505               0.833
# 27    LeBron James             0.535       0.520               0.667
# 28    LeBron James             0.533       0.518               0.667
# 29     Kobe Bryant             0.523       0.488               0.833
# 30     Kobe Bryant             0.520       0.485               0.833
# 31  Michael Jordan             0.518       0.465               1.000
# 32     Kobe Bryant             0.514       0.478               0.833
# 33     Kobe Bryant             0.511       0.475               0.833
# 34    LeBron James             0.501       0.482               0.667
# 35    LeBron James             0.496       0.477               0.667
# 36    LeBron James             0.483       0.463               0.667
# 37     Kobe Bryant             0.480       0.441               0.833
# 38     Kobe Bryant             0.480       0.440               0.833
# 39    LeBron James             0.467       0.445               0.667
# 40     Kobe Bryant             0.466       0.426               0.833
# 41  Michael Jordan             0.446       0.384               1.000
# 42     Kobe Bryant             0.445       0.402               0.833
# 43     Kobe Bryant             0.443       0.400               0.833
# 44     Kobe Bryant             0.436       0.392               0.833
# 45     Kobe Bryant             0.435       0.391               0.833
# 46     Kobe Bryant             0.435       0.391               0.833
# 47     Kobe Bryant             0.433       0.388               0.833
# 48    LeBron James             0.419       0.391               0.667
# 49  Michael Jordan             0.411       0.346               1.000
# 50     Kobe Bryant             0.401       0.353               0.833
# 51  Michael Jordan             0.385       0.316               1.000
# 52     Kobe Bryant             0.359       0.306               0.833
# 53     Kobe Bryant             0.354       0.301               0.833
# 54     Kobe Bryant             0.331       0.276               0.833
# 55    LeBron James             0.306       0.266               0.667
# 56     Kobe Bryant             0.304       0.245               0.833
# 57     Kobe Bryant             0.294       0.234               0.833

# %%
goat_career_final = (
    goat_final
    .groupby("PLAYER_NAME", as_index=False)
    .mean(numeric_only=True)
)

# %%
goat_career_final = goat_career_final.sort_values(
    "GOAT_INDEX_FINAL",
    ascending=False
)

# %%
ranking_final = goat_career_final[[
    "PLAYER_NAME",
    "GOAT_INDEX_FINAL",
    "GOAT_INDEX",
    "CHAMPIONSHIPS_NORM"
]].round(3)

ranking_final
# Out:
#       PLAYER_NAME  GOAT_INDEX_FINAL  GOAT_INDEX  CHAMPIONSHIPS_NORM
# 2  Michael Jordan             0.581       0.534               1.000
# 1    LeBron James             0.562       0.551               0.667
# 0     Kobe Bryant             0.435       0.391               0.833

# %%
ranking_final = ranking_final.reset_index(drop=True)
ranking_final.index += 1
ranking_final.index.name = "RANK"
ranking_final
# Out:
#          PLAYER_NAME  GOAT_INDEX_FINAL  GOAT_INDEX  CHAMPIONSHIPS_NORM
# RANK
# 1     Michael Jordan             0.581       0.534               1.000
# 2       LeBron James             0.562       0.551               0.667
# 3        Kobe Bryant             0.435       0.391               0.833
